# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the citypy to get the nearest city.
from citipy import citipy

# %%
# list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
print(cities[0])
print(cities)
# Out:
# 768
# waingapu
# ['waingapu', 'hithadhoo', 'barrow', 'taolanaro', 'the valley', 'belushya guba', 'yellowknife', 'grand gaube', 'ushuaia', 'bethel', 'hobyo', 'dingle', 'lodwar', 'rikitea', 'chautla', 'naifaru', 'mataura', 'butaritari', 'emerald', 'victoria', 'makubetsu', 'tezu', 'ust-tsilma', 'sijunjung', 'bull savanna', 'bandarbeyla', 'rawannawi', 'atuona', 'salinas', 'olinda', 'dikson', 'khatanga', 'saleaula', 'thompson', 'port macquarie', 'naryan-mar', 'illoqqortoormiut', 'ostrovnoy', 'punta arenas', 'bluff', 'cherskiy', 'juba', 'hamilton', 'hilo', 'vaini', 'alice springs', 'sambava', 'karratha', 'makali', 'esperance', 'albany', 'avarua', 'ballina', 'mangai', 'cape town', 'keflavik', 'jamestown', 'tasbuget', 'ponta do sol', 'new norfolk', 'halifax', 'azua', 'mayo', 'puerto ayora', 'hermanus', 'semporna', 'amderma', 'aklavik', 'kavieng', 'puerto baquerizo moreno', 'bengkulu', 'kahului', 'krasnaya gorka', 'roald', 'skagastrond', 'altenholz', 'haines junction', 'dunedin', 'tuatapere', 'puerto maldonado', 'nemuro', 'ribeira grande', 'port elizabeth', 'tsihombe', 'ust-ilimsk', 'khorixas', 'nushki', 'cidreira', 'mahebourg', 'pacific grove', 'pangkalanbuun', 'mrirt', 'bukavu', 'geraldton', 'qaanaaq', 'chagda', 'tacna', 'saint george', 'narrabri', 'salinopolis', 'busselton', 'huayang', 'arraial do cabo', 'bambous virieux', 'faya', 'kantang', 'bafq', 'svetlyy', 'berlevag', 'bredasdorp', 'hobart', 'komsomolskiy', 'neiafu', 'griffith', 'anloga', 'solnechnyy', 'yeppoon', 'ewa beach', 'muros', 'adrar', 'espinosa', 'krasyliv', 'severo-kurilsk', 'evensk', 'santa maria', 'north platte', 'hovd', 'ankang', 'sao miguel do tapuio', 'kiama', 'lebu', 'kapaa', 'saint-max', 'krasnoselkup', 'cockburn town', 'georgetown', 'kayerkan', 'margate', 'paradwip', 'luderitz', 'klaksvik', 'betioky', 'nhulunbuy', 'port alfred', 'faanui', 'torbay', 'katsuura', 'kodiak', 'bur gabo', 'urumqi', 'makakilo city', 'ahuimanu', 'huanuco', 'severnyy', 'grand river south east', 'neuquen', 'praia da vitoria', 'chuy', 'saint-pierre', 'horten', 'tuktoyaktuk', 'castro', 'karaul', 'nizhneyansk', 'vardo', 'kemi', 'waynesboro', 'russell', 'ilulissat', 'talcahuano', 'champerico', 'garbolovo', 'bolungarvik', 'los llanos de aridane', 'umzimvubu', 'san ignacio', 'kozhevnikovo', 'leningradskiy', 'guerrero', 'porbandar', 'madang', 'cabras', 'saint anthony', 'quatre cocos', 'mount isa', 'tungkang', 'barentsburg', 'linxia', 'fortuna', 'saskylakh', 'kalabo', 'petropavlovsk-kamchatskiy', 'arcata', 'portland', 'selfoss', 'lavrentiya', 'tual', 'te anau', 'singarayakonda', 'araouane', 'guerrero negro', 'east london', 'khor', 'tiksi', 'isangel', 'tasiilaq', 'egvekinot', 'jining', 'alofi', 'port-gentil', 'artyk', 'kavaratti', 'vila velha', 'sorong', 'jamame', 'tekirdag', 'zhuanghe', 'karpathos', 'tomatlan', 'longyearbyen', 'rocha', 'yaan', 'boyolangu', 'airai', 'tecoanapa', 'aflu', 'mys shmidta', 'ahipara', 'dire', 'arlit', 'ko samui', 'kargat', 'sentyabrskiy', 'wewak', 'byron bay', 'nikolskoye', 'afmadu', 'dalinghe', 'gibraleon', 'sidi ali', 'stupino', 'lensk', 'sur', 'harnosand', 'kaitangata', 'kuche', 'new glasgow', 'garden city', 'codrington', 'safwah', 'grindavik', 'juifang', 'stephenville', 'axim', 'kaputa', 'husavik', 'yerbogachen', 'upernavik', 'omsukchan', 'batagay-alyta', 'nabire', 'vangaindrano', 'krasnoarmeysk', 'bara', 'souillac', 'toliary', 'vila', 'mar del plata', 'vanavara', 'marsh harbour', 'erzin', 'honningsvag', 'san cristobal', 'kimbe', 'sainte-maxime', 'attawapiskat', 'naruto', 'saint-philippe', 'hofn', 'udachnyy', 'turukhansk', 'talnakh', 'tabat', 'iracoubo', 'itarema', 'khandyga', 'north bend', 'carberry', 'canico', 'tete', 'hasaki', 'lata', 'nador', 'mangan', 'deputatskiy', 'ozernovskiy', 'kaili', 'qovlar', 'yala', 'cuamba', 'hanzhong', 'carnarvon', 'iquitos', 'umarkot', 'pangnirtung', 'dukat', 'sikasso', 'richards bay', 'tautira', 'monrovia', 'baykit', 'tamandare', 'bagnes', 'pisco', 'rawson', 'nanortalik', 'clyde river', 'hammerfest', 'san juan', 'kokopo', 'buraydah', 'ipixuna', 'gre ...

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Data API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#For sleep timer
import time

# %%
# empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
     # Run an API request for each of the cities.
    try:

        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]

        city_lat = city_weather["coord"]["lat"]

        city_lng = city_weather["coord"]["lon"]

        city_max_temp = city_weather["main"]["temp_max"]

        city_humidity = city_weather["main"]["humidity"]

        city_clouds = city_weather["clouds"]["all"]

        city_wind = city_weather["wind"]["speed"]

        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waingapu
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | the valley
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | grand gaube
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | hobyo
# Processing Record 12 of Set 1 | dingle
# Processing Record 13 of Set 1 | lodwar
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | chautla
# City not found. Skipping...
# Processing Record 16 of Set 1 | naifaru
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | emerald
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | makubetsu
# Processing Record 22 of Set 1 | tezu
# Processing Record 23 of Set 1 | ust-tsilma
# Processing Record 24 of Set 1 | sijunjung
# Processing Record 25 of Set 1 | bull savanna
# Processing Record 26 of Set 1 | bandarbeyla
# Processing Record 27 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | salinas
# Processing Record 30 of Set 1 | olinda
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | port macquarie
# Processing Record 36 of Set 1 | naryan-mar
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | ostrovnoy
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | juba
# Processing Record 43 of Set 1 | hamilton
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | alice springs
# Processing Record 47 of Set 1 | sambava
# Processing Record 48 of Set 1 | karratha
# Processing Record 49 of Set 1 | makali
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | ballina
# Processing Record 4 of Set 2 | mangai
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | keflavik
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | halifax
# Processing Record 12 of Set 2 | azua
# Processing Record 13 of Set 2 | mayo
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | semporna
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | aklavik
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | puerto baquerizo moreno
# Processing Record 21 of Set 2 | bengkulu
# Processing Record 22 of Set 2 | kahului
# Processing Record 23 of Set 2 | krasnaya gorka
# Processing Record 24 of Set 2 | roald
# Processing Record 25 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 26 of Set 2 | altenholz
# Processing Record 27 of Set 2 | haines junction
# Processing Record 28 of Set 2 | dunedin
# Processing Record 29 of Set 2 | tuatapere
# Processing Record 30 of Set 2 | puerto maldonado
# Processing Record 31 of Set 2 | nemuro
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | ust-ilimsk
# Processing Record 36 of Set 2 | khorixas
# Processing Record 37 of Set 2 | nushki
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | pacific grove
# Processing Record 41 of Set 2 | pangkalanbuun
# Processing Record 42 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 2 | bukavu
# Processing Record 44 of Set 2 | geraldton
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 2 | tacna
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | narrabri
# Processing Record 50 of Set 2 | salinopolis
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | huayang
# Processing Record 3 of Set 3 | arraial do cabo
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | faya
# Processing Record 6 of Set 3 | kantang
# Processing Record 7 of Set 3 | bafq
# Processing Record 8 of Set 3 | svetlyy
# Processing Record 9 of Set 3 | berlevag
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | komsomolskiy
# Processing Record 13 of Set 3 | neiafu
# Processing Record 14 of Set 3 | griffith
# Processing Record 15 of Set 3 | anloga
# Processing Record 16 of Set 3 | solnechnyy
# Processing Record 17 of Set 3 | yeppoon
# Processing Record 18 of Set 3 | ewa beach
# Processing Record 19 of Set 3 | muros
# Processing Record 20 of Set 3 | adrar
# Processing Record 21 of Set 3 | espinosa
# Processing Record 22 of Set 3 | krasyliv
# Processing Record 23 of Set 3 | severo-kurilsk
# Processing Record 24 of Set 3 | evensk
# Processing Record 25 of Set 3 | santa maria
# Processing Record 26 of Set 3 | north platte
# Processing Record 27 of Set 3 | hovd
# Processing Record 28 of Set 3 | ankang
# Processing Record 29 of Set 3 | sao miguel do tapuio
# Processing Record 30 of Set 3 | kiama
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | kapaa
# Processing Record 33 of Set 3 | saint-max
# Processing Record 34 of Set 3 | krasnoselkup
# Processing Record 35 of Set 3 | cockburn town
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | kayerkan
# Processing Record 38 of Set 3 | margate
# Processing Record 39 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | klaksvik
# Processing Record 42 of Set 3 | betioky
# Processing Record 43 of Set 3 | nhulunbuy
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | katsuura
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 3 | urumqi
# Processing Record 1 of Set 4 | makakilo city
# Processing Record 2 of Set 4 | ahuimanu
# Processing Record 3 of Set 4 | huanuco
# Processing Record 4 of Set 4 | severnyy
# Processing Record 5 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 4 | neuquen
# Processing Record 7 of Set 4 | praia da vitoria
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | saint-pierre
# Processing Record 10 of Set 4 | horten
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | vardo
# Processing Record 16 of Set 4 | kemi
# Processing Record 17 of Set 4 | waynesboro
# Processing Record 18 of Set 4 | russell
# Processing Record 19 of Set 4 | ilulissat
# Processing Record 20 of Set 4 | talcahuano
# Processing Record 21 of Set 4 | champerico
# Processing Record 22 of Set 4 | garbolovo
# Processing Record 23 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 4 | los llanos de aridane
# Processing Record 25 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 4 | san ignacio
# Processing Record 27 of Set 4 | kozhevnikovo
# Processing Record 28 of Set 4 | leningradskiy
# Processing Record 29 of Set 4 | guerrero
# Processing Record 30 of Set 4 | porbandar
# Processing Record 31 of Set 4 | madang
# Processing Record 32 of Set 4 | cabras
# Processing Record 33 of Set 4 | saint anthony
# Processing Record 34 of Set 4 | quatre cocos
# Processing Record 35 of Set 4 | mount isa
# Processing Record 36 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 37 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 4 | linxia
# Processing Record 39 of Set 4 | fortuna
# Processing Record 40 of Set 4 | saskylakh
# Processing Record 41 of Set 4 | kalabo
# Processing Record 42 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 4 | arcata
# Processing Record 44 of Set 4 | portland
# Processing Record 45 of Set 4 | selfoss
# Processing Record 46 of Set 4 | lavrentiya
# Processing Record 47 of Set 4 | tual
# Processing Record 48 of Set 4 | te anau
# Processing Record 49 of Set 4 | singarayakonda
# Processing Record 50 of Set 4 | araouane
# Processing Record 1 of Set 5 | guerrero negro
# Processing Record 2 of Set 5 | east london
# Processing Record 3 of Set 5 | khor
# Processing Record 4 of Set 5 | tiksi
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | egvekinot
# Processing Record 8 of Set 5 | jining
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | port-gentil
# Processing Record 11 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 5 | kavaratti
# Processing Record 13 of Set 5 | vila velha
# Processing Record 14 of Set 5 | sorong
# Processing Record 15 of Set 5 | jamame
# Processing Record 16 of Set 5 | tekirdag
# Processing Record 17 of Set 5 | zhuanghe
# Processing Record 18 of Set 5 | karpathos
# Processing Record 19 of Set 5 | tomatlan
# Processing Record 20 of Set 5 | longyearbyen
# Processing Record 21 of Set 5 | rocha
# Processing Record 22 of Set 5 | yaan
# Processing Record 23 of Set 5 | boyolangu
# Processing Record 24 of Set 5 | airai
# Processing Record 25 of Set 5 | tecoanapa
# Processing Record 26 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 5 | ahipara
# Processing Record 29 of Set 5 | dire
# Processing Record 30 of Set 5 | arlit
# Processing Record 31 of Set 5 | ko samui
# Processing Record 32 of Set 5 | kargat
# Processing Record 33 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | wewak
# Processing Record 35 of Set 5 | byron bay
# Processing Record 36 of Set 5 | nikolskoye
# Processing Record 37 of Set 5 | afmadu
# City not found. Skipping...
# Processing Record 38 of Set 5 | dalinghe
# City not found. Skipping...
# Processing Record 39 of Set 5 | gibraleon
# Processing Record 40 of Set 5 | sidi ali
# Processing Record 41 of Set 5 | stupino
# Processing Record 42 of Set 5 | lensk
# Processing Record 43 of Set 5 | sur
# Processing Record 44 of Set 5 | harnosand
# Processing Record 45 of Set 5 | kaitangata
# Processing Record 46 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 5 | new glasgow
# Processing Record 48 of Set 5 | garden city
# Processing Record 49 of Set 5 | codrington
# Processing Record 50 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 1 of Set 6 | grindavik
# Processing Record 2 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 3 of Set 6 | stephenville
# Processing Record 4 of Set 6 | axim
# Processing Record 5 of Set 6 | kaputa
# Processing Record 6 of Set 6 | husavik
# Processing Record 7 of Set 6 | yerbogachen
# Processing Record 8 of Set 6 | upernavik
# Processing Record 9 of Set 6 | omsukchan
# Processing Record 10 of Set 6 | batagay-alyta
# Processing Record 11 of Set 6 | nabire
# Processing Record 12 of Set 6 | vangaindrano
# Processing Record 13 of Set 6 | krasnoarmeysk
# Processing Record 14 of Set 6 | bara
# Processing Record 15 of Set 6 | souillac
# Processing Record 16 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 6 | vila
# Processing Record 18 of Set 6 | mar del plata
# Processing Record 19 of Set 6 | vanavara
# Processing Record 20 of Set 6 | marsh harbour
# Processing Record 21 of Set 6 | erzin
# Processing Record 22 of Set 6 | honningsvag
# Processing Record 23 of Set 6 | san cristobal
# Processing Record 24 of Set 6 | kimbe
# Processing Record 25 of Set 6 | sainte-maxime
# Processing Record 26 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 6 | naruto
# Processing Record 28 of Set 6 | saint-philippe
# Processing Record 29 of Set 6 | hofn
# Processing Record 30 of Set 6 | udachnyy
# Processing Record 31 of Set 6 | turukhansk
# Processing Record 32 of Set 6 | talnakh
# Processing Record 33 of Set 6 | tabat
# Processing Record 34 of Set 6 | iracoubo
# Processing Record 35 of Set 6 | itarema
# Processing Record 36 of Set 6 | khandyga
# Processing Record 37 of Set 6 | north bend
# Processing Record 38 of Set 6 | carberry
# Processing Record 39 of Set 6 | canico
# Processing Record 40 of Set 6 | tete
# Processing Record 41 of Set 6 | hasaki
# Processing Record 42 of Set 6 | lata
# Processing Record 43 of Set 6 | nador
# Processing Record 44 of Set 6 | mangan
# Processing Record 45 of Set 6 | deputatskiy
# Processing Record 46 of Set 6 | ozernovskiy
# Processing Record 47 of Set 6 | kaili
# Processing Record 48 of Set 6 | qovlar
# Processing Record 49 of Set 6 | yala
# Processing Record 50 of Set 6 | cuamba
# Processing Record 1 of Set 7 | hanzhong
# Processing Record 2 of Set 7 | carnarvon
# Processing Record 3 of Set 7 | iquitos
# Processing Record 4 of Set 7 | umarkot
# Processing Record 5 of Set 7 | pangnirtung
# Processing Record 6 of Set 7 | dukat
# Processing Record 7 of Set 7 | sikasso
# Processing Record 8 of Set 7 | richards bay
# Processing Record 9 of Set 7 | tautira
# Processing Record 10 of Set 7 | monrovia
# Processing Record 11 of Set 7 | baykit
# Processing Record 12 of Set 7 | tamandare
# Processing Record 13 of Set 7 | bagnes
# Processing Record 14 of Set 7 | pisco
# Processing Record 15 of Set 7 | rawson
# Processing Record 16 of Set 7 | nanortalik
# Processing Record 17 of Set 7 | clyde river
# Processing Record 18 of Set 7 | hammerfest
# Processing Record 19 of Set 7 | san juan
# Processing Record 20 of Set 7 | kokopo
# Processing Record 21 of Set 7 | buraydah
# Processing Record 22 of Set 7 | ipixuna
# Processing Record 23 of Set 7 | great bend
# Processing Record 24 of Set 7 | natal
# Processing Record 25 of Set 7 | kampot
# Processing Record 26 of Set 7 | sarangani
# Processing Record 27 of Set 7 | gizo
# Processing Record 28 of Set 7 | kidal
# Processing Record 29 of Set 7 | sao filipe
# Processing Record 30 of Set 7 | new sibonga
# Processing Record 31 of Set 7 | landshut
# Processing Record 32 of Set 7 | requena
# Processing Record 33 of Set 7 | aykhal
# Processing Record 34 of Set 7 | kisangani
# Processing Record 35 of Set 7 | aksarka
# Processing Record 36 of Set 7 | lafiagi
# Processing Record 37 of Set 7 | vao
# Processing Record 38 of Set 7 | hope
# Processing Record 39 of Set 7 | keningau
# Processing Record 40 of Set 7 | nizhnyaya omka
# Processing Record 41 of Set 7 | provideniya
# Processing Record 42 of Set 7 | araucaria
# Processing Record 43 of Set 7 | baijiantan
# Processing Record 44 of Set 7 | omboue
# Processing Record 45 of Set 7 | monticello
# Processing Record 46 of Set 7 | itororo
# Processing Record 47 of Set 7 | chokurdakh
# Processing Record 48 of Set 7 | ayagoz
# Processing Record 49 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 50 of Set 7 | talara
# Processing Record 1 of Set 8 | cayenne
# Processing Record 2 of Set 8 | whyalla
# Processing Record 3 of Set 8 | fort nelson
# Processing Record 4 of Set 8 | aljezur
# Processing Record 5 of Set 8 | suntar
# Processing Record 6 of Set 8 | ende
# Processing Record 7 of Set 8 | bouloupari
# Processing Record 8 of Set 8 | ust-ishim
# Processing Record 9 of Set 8 | windhoek
# Processing Record 10 of Set 8 | almonte
# Processing Record 11 of Set 8 | lompoc
# Processing Record 12 of Set 8 | inndyr
# Processing Record 13 of Set 8 | toledo
# Processing Record 14 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 15 of Set 8 | zambezi
# Processing Record 16 of Set 8 | parfenyevo
# Processing Record 17 of Set 8 | zhezkazgan
# Processing Record 18 of Set 8 | nioki
# Processing Record 19 of Set 8 | jutai
# Processing Record 20 of Set 8 | lumphat
# Processing Record 21 of Set 8 | kosh-agach
# Processing Record 22 of Set 8 | pevek
# Processing Record 23 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 8 | khorinsk
# Processing Record 25 of Set 8 | denpasar
# Processing Record 26 of Set 8 | lasa
# Processing Record 27 of Set 8 | goyty
# Processing Record 28 of Set 8 | pandan
# Processing Record 29 of Set 8 | barroualie
# City not found. Skipping...
# Processing Record 30 of Set 8 | taksimo
# Processing Record 31 of Set 8 | port keats
# Processing Record 32 of Set 8 | yulara
# Processing Record 33 of Set 8 | porto velho
# Processing Record 34 of Set 8 | gland
# Processing Record 35 of Set 8 | fairbanks
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | pindiga
# Processing Record 38 of Set 8 | acarau
# Processing Record 39 of Set 8 | port hardy
# Processing Record 40 of Set 8 | port blair
# Processing Record 41 of Set 8 | santander
# Processing Record 42 of Set 8 | dzaoudzi
# Processing Record 43 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 8 | guangyuan
# Processing Record 45 of Set 8 | ilhabela
# Processing Record 46 of Set 8 | sitka
# Processing Record 47 of Set 8 | thinadhoo
# Processing Record 48 of Set 8 | majene
# Processing Record 49 of Set 8 | moa
# Processing Record 50 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 1 of Set 9 | kainantu
# Processing Record 2 of Set 9 | hirara
# Processing Record 3 of Set 9 | bilma
# Processing Record 4 of Set 9 | tarakan
# Processing Record 5 of Set 9 | okha
# Processing Record 6 of Set 9 | lagoa
# Processing Record 7 of Set 9 | castanos
# Processing Record 8 of Set 9 | prince rupert
# Processing Record 9 of Set 9 | tubuala
# Processing Record 10 of Set 9 | zherdevka
# Processing Record 11 of Set 9 | bonavista
# Processing Record 12 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 13 of Set 9 | buluang
# Processing Record 14 of Set 9 | panaba
# Processing Record 15 of Set 9 | nyurba
# Processing Record 16 of Set 9 | yar-sale
# Processing Record 17 of Set 9 | mehamn
# Processing Record 18 of Set 9 | hokitika
# Processing Record 19 of Set 9 | alice
# Processing Record 20 of Set 9 | hermiston
# Processing Record 21 of Set 9 | flinders
# Processing Record 22 of Set 9 | celestun
# Processing Record 23 of Set 9 | panacan
# Processing Record 24 of Set 9 | yenagoa
# Processing Record 25 of Set 9 | camacha
# Processing Record 26 of Set 9 | port lincoln
# Processing Record 27 of Set 9 | nishihara
# Processing Record 28 of Set 9 | comodoro rivadavia
# Processing Record 29 of Set 9 | hami
# Processing Record 30 of Set 9 | cap-chat
# Processing Record 31 of Set 9 | kichera
# Processing Record 32 of Set 9 | naze
# Processing Record 33 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 9 | tadine
# Processing Record 35 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 9 | norman wells
# Processing Record 37 of Set 9 | vanimo
# Processing Record 38 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 9 | high point
# Processing Record 40 of Set 9 | high rock
# Processing Record 41 of Set 9 | mozarlandia
# Processing Record 42 of Set 9 | pucallpa
# Processing Record 43 of Set 9 | shestakovo
# Processing Record 44 of Set 9 | teguldet
# Processing Record 45 of Set 9 | dattapur
# Processing Record 46 of Set 9 | saint-francois
# Processing Record 47 of Set 9 | lancaster
# Processing Record 48 of Set 9 | saldanha
# Processing Record 49 of Set 9 | zhigansk
# Processing Record 50 of Set 9 | pafos
# Processing Record 1 of Set 10 | monforte de lemos
# Processing Record 2 of Set 10 | salalah
# Processing Record 3 of Set 10 | kasempa
# Processing Record 4 of Set 10 | constitucion
# Processing Record 5 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 10 | palmer
# Processing Record 7 of Set 10 | ivanteyevka
# Processing Record 8 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 10 | gat
# Processing Record 10 of Set 10 | tiruchchendur
# Processing Record 11 of Set 10 | dhidhdhoo
# Processing Record 12 of Set 10 | puerto palomas
# Processing Record 13 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 14 of Set 10 | banjar
# Processing Record 15 of Set 10 | san quintin
# Processing Record 16 of Set 10 | sembe
# Processing Record 17 of Set 10 | newport
# Processing Record 18 of Set 10 | chapais
# Processing Record 19 of Set 10 | shebunino
# Processing Record 20 of Set 10 | manaure
# Processing Record 21 of Set 10 | paita
# Processing Record 22 of Set 10 | borovoy
# Processing Record 23 of Set 10 | porecatu
# Processing Record 24 of Set 10 | camopi
# Processing Record 25 of Set 10 | plainview
# Processing Record 26 of Set 10 | floresti
# Processing Record 27 of Set 10 | shwebo
# Processing Record 28 of Set 10 | tilichiki
# Processing Record 29 of Set 10 | yei
# Processing Record 30 of Set 10 | kandrian
# Processing Record 31 of Set 10 | verkhnyaya inta
# Processing Record 32 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 10 | duobao
# Processing Record 35 of Set 10 | maracas
# Processing Record 36 of Set 10 | alappuzha
# Processing Record 37 of Set 10 | fochville
# Processing Record 38 of Set 10 | xuddur
# Processing Record 39 of Set 10 | cumaru
# Processing Record 40 of Set 10 | zhangye
# Processing Record 41 of Set 10 | penzance
# Processing Record 42 of Set 10 | morondava
# Processing Record 43 of Set 10 | tehachapi
# Processing Record 44 of Set 10 | pundaguitan
# Processing Record 45 of Set 10 | makung
# City not found. Skipping...
# Processing Record 46 of Set 10 | catamarca
# Processing Record 47 of Set 10 | saint-joseph
# Processing Record 48 of Set 10 | castle rock
# Processing Record 49 of Set 10 | pemangkat
# Processing Record 50 of Set 10 | marion
# Processing Record 1 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 2 of Set 11 | havelock
# Processing Record 3 of Set 11 | ludwigslust
# Processing Record 4 of Set 11 | rio grande
# Processing Record 5 of Set 11 | merauke
# Processing Record 6 of Set 11 | riachao
# Processing Record 7 of Set 11 | bangassou
# Processing Record 8 of Set 11 | camacari
# Processing Record 9 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 10 of Set 11 | lakes entrance
# Processing Record 11 of Set 11 | biloela
# Processing Record 12 of Set 11 | rio gallegos
# Processing Record 13 of Set 11 | necochea
# Processing Record 14 of Set 11 | palu
# Processing Record 15 of Set 11 | araripina
# Processing Record 16 of Set 11 | anadyr
# Processing Record 17 of Set 11 | riviere-au-renard
# Processing Record 18 of Set 11 | kununurra
# Processing Record 19 of Set 11 | voi
# Processing Record 20 of Set 11 | sibu
# Processing Record 21 of Set 11 | alegrete
# Processing Record 22 of Set 11 | serra talhada
# Processing Record 23 of Set 11 | tulun
# Processing Record 24 of Set 11 | terrace
# Processing Record 25 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 11 | tabas
# Processing Record 27 of Set 11 | winsum
# Processing Record 28 of Set 11 | coihaique
# Processing Record 29 of Set 11 | allen
# Processing Record 30 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 11 | bathsheba
# Processing Record 32 of Set 11 | bloomington
# Processing Record 33 of Set 11 | ashtabula
# Processing Record 34 of Set 11 | kishapu
# Processing Record 35 of Set 11 | poya
# Processing Record 36 of Set 11 | xai-xai
# Processing Record 37 of Set 11 | bereda
# Processing Record 38 of Set 11 | alamogordo
# Processing Record 39 of Set 11 | igarka
# Processing Record 40 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 11 | skovorodino
# Processing Record 42 of Set 11 | arrifes
# Processing Record 43 of Set 11 | caravelas
# Processing Record 44 of Set 11 | atherton
# Processing Record 45 of Set 11 | giarmata
# Processing Record 46 of Set 11 | olga
# Processing Record 47 of Set 11 | vestmanna
# Processing Record 48 of Set 11 | fayaoue
# Processing Record 49 of Set 11 | nsanje
# Processing Record 50 of Set 11 | eenhana
# Processing Record 1 of Set 12 | bolzano
# Processing Record 2 of Set 12 | rezh
# Processing Record 3 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 12 | grand-lahou
# Processing Record 5 of Set 12 | mhlambanyatsi
# Processing Record 6 of Set 12 | arawa
# Processing Record 7 of Set 12 | storforshei
# Processing Record 8 of Set 12 | fort-shevchenko
# Processing Record 9 of Set 12 | bahir dar
# Processing Record 10 of Set 12 | scarborough
# Processing Record 11 of Set 12 | tipitapa
# Processing Record 12 of Set 12 | wasilla
# Processing Record 13 of Set 12 | astoria
# Processing Record 14 of Set 12 | nkayi
# Processing Record 15 of Set 12 | aksu
# Processing Record 16 of Set 12 | lorengau
# Processing Record 17 of Set 12 | nieuw amsterdam
# Processing Record 18 of Set 12 | sines
# Processing Record 19 of Set 12 | trat
# Processing Record 20 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 21 of Set 12 | opuwo
# Processing Record 22 of Set 12 | asau
# Processing Record 23 of Set 12 | plettenberg bay
# Processing Record 24 of Set 12 | ajdabiya
# Processing Record 25 of Set 12 | qasigiannguit
# Processing Record 26 of Set 12 | belmonte
# Processing Record 27 of Set 12 | maragheh
# Processing Record 28 of Set 12 | pryazha
# Processing Record 29 of Set 12 | santa rosa
# Processing Record 30 of Set 12 | nome
# Processing Record 31 of Set 12 | xiuyan
# Processing Record 32 of Set 12 | itoman
# Processing Record 33 of Set 12 | atbasar
# Processing Record 34 of Set 12 | cabo san lucas
# Processing Record 35 of Set 12 | srednekolymsk
# Processing Record 36 of Set 12 | yakeshi
# Processing Record 37 of Set 12 | taos
# Processing Record 38 of Set 12 | sangar
# Processing Record 39 of Set 12 | shingu
# Processing Record 40 of Set 12 | meulaboh
# Processing Record 41 of Set 12 | laguna
# Processing Record 42 of Set 12 | arkhangelos
# City not found. Skipping...
# Processing Record 43 of Set 12 | waipawa
# Processing Record 44 of Set 12 | carmo do paranaiba
# Processing Record 45 of Set 12 | sovetskaya
# Processing Record 46 of Set 12 | san patricio
# Processing Record 47 of Set 12 | orumiyeh
# Processing Record 48 of Set 12 | porto walter
# Processing Record 49 of Set 12 | udankudi
# Processing Record 50 of Set 12 | mollendo
# Processing Record 1 of Set 13 | san miguel
# Processing Record 2 of Set 13 | radcliff
# Processing Record 3 of Set 13 | rosarito
# Processing Record 4 of Set 13 | vaitape
# Processing Record 5 of Set 13 | paamiut
# Processing Record 6 of Set 13 | sept-iles
# Processing Record 7 of Set 13 | vila do maio
# Processing Record 8 of Set 13 | njombe
# Processing Record 9 of Set 13 | zharkent
# Processing Record 10 of Set 13 | ryotsu
# Processing Record 11 of Set 13 | west wendover
# Processing Record 12 of Set 13 | conde
# Processing Record 13 of Set 13 | pimentel
# Processing Record 14 of Set 13 | ketchikan
# Processing Record 15 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 13 | blagoyevo
# Processing Record 17 of Set 13 | suffern
# Processing Record 18 of Set 13 | aboso
# Processing Record 19 of Set 13 | buchanan
# Processing Record 20 of Set 13 | nicoya
# Processing Record 21 of Set 13 | morbach
# Processing Record 22 of Set 13 | la solana
# Processing Record 23 of Set 13 | vallenar
# Processing Record 24 of Set 13 | ziyamet
# City not found. Skipping...
# Processing Record 25 of Set 13 | ambilobe
# Processing Record 26 of Set 13 | andenes
# Processing Record 27 of Set 13 | asyut
# Processing Record 28 of Set 13 | arman
# Processing Record 29 of Set 13 | phan thiet
# Processing Record 30 of Set 13 | salto
# Processing Record 31 of Set 13 | gambela
# Processing Record 32 of Set 13 | ouricuri
# Processing Record 33 of Set 13 | jiuquan
# Processing Record 34 of Set 13 | petropavlovskoye
# Processing Record 35 of Set 13 | littleton
# Processing Record 36 of Set 13 | guaraniacu
# Processing Record 37 of Set 13 | noyabrsk
# Processing Record 38 of Set 13 | gwadar
# Processing Record 39 of Set 13 | fare
# Processing Record 40 of Set 13 | mandurah
# Processing Record 41 of Set 13 | klyuchi
# Processing Record 42 of Set 13 | stornoway
# Processing Record 43 of Set 13 | stamsund
# City not found. Skipping...
# Processing Record 44 of Set 13 | durban
# Processing Record 45 of Set 13 | tessalit
# Processing Record 46 of Set 13 | coolum beach
# Processing Record 47 of Set 13 | bani
# Processing Record 48 of Set 13 | primorsk
# Processing Record 49 of Set 13 | bocaranga
# City not found. Skipping...
# Processing Record 50 of Set 13 | sal rei
# Processing Record 1 of Set 14 | honiara
# Processing Record 2 of Set 14 | insar
# Processing Record 3 of Set 14 | samana
# Processing Record 4 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 14 | sao raimundo das mangabeiras
# Processing Record 6 of Set 14 | baiyin
# Processing Record 7 of Set 14 | kozhva
# Processing Record 8 of Set 14 | roche-la-moliere
# Processing Record 9 of Set 14 | college
# Processing Record 10 of Set 14 | nakamura
# Processing Record 11 of Set 14 | tateyama
# Processing Record 12 of Set 14 | namatanai
# Processing Record 13 of Set 14 | sao joao da barra
# Processing Record 14 of Set 14 | bourail
# Processing Record 15 of Set 14 | bansud
# Processing Record 16 of Set 14 | timberlake
# Processing Record 17 of Set 14 | lynn haven
# Processing Record 18 of Set 14 | sheridan
# Processing Record 19 of Set 14 | teahupoo
# Processing Record 20 of Set 14 | tashtyp
# Processing Record 21 of Set 14 | puerto carreno
# Processing Record 22 of Set 14 | kletskaya
# Processing Record 23 of Set 14 | crab hill
# City not found. Skipping...
# Processing Record 24 of Set 14 | harper
# Processing Record 25 of Set 14 | alenquer
# Processing Record 26 of Set 14 | montes claros
# Processing Record 27 of Set 14 | whitehorse
# Processing Record 28 of Set 14 | narsaq
# Processing Record 29 of Set 14 | bosaso
# Processing Record 30 of Set 14 | mercedes
# Processing Record 31 of Set 14 | anito
# Processing Record 32 of Set 14 | rock springs
# Processing Record 33 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 14 | bhimunipatnam
# Processing Record 35 of Set 14 | ortigueira
# Processing Record 36 of Set 14 | menongue
# Processing Record 37 of Set 14 | sibi
# Processing Record 38 of Set 14 | novo aripuana
# Processing Record 39 of Set 14 | kontagora
# Processing Record 40 of Set 14 | fleetwood
# Processing Record 41 of Set 14 | kalmunai
# Processing Record 42 of Set 14 | kazachinskoye
# Processing Record 43 of Set 14 | dalvik
# Processing Record 44 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 46 of Set 14 | chumikan
# Processing Record 47 of Set 14 | mount gambier
# Processing Record 48 of Set 14 | boundiali
# Processing Record 49 of Set 14 | sinnamary
# Processing Record 50 of Set 14 | mungwi
# Processing Record 1 of Set 15 | sorland
# Processing Record 2 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 3 of Set 15 | poltavka
# Processing Record 4 of Set 15 | mnogovershinnyy
# Processing Record 5 of Set 15 | saint-augustin
# Processing Record 6 of Set 15 | rapid valley
# Processing Record 7 of Set 15 | gamba
# Processing Record 8 of Set 15 | kenai
# Processing Record 9 of Set 15 | maceio
# Processing Record 10 of Set 15 | haverfordwest
# Processing Record 11 of Set 15 | mtwara
# Processing Record 12 of Set 15 | kutum
# Processing Record 13 of Set 15 | san ramon
# Processing Record 14 of Set 15 | farafangana
# Processing Record 15 of Set 15 | punta alta
# Processing Record 16 of Set 15 | samarai
# Processing Record 17 of Set 15 | canete
# Processing Record 18 of Set 15 | salym
# Processing Record 19 of Set 15 | tartus
# Processing Record 20 of Set 15 | port hawkesbury
# Processing Record 21 of Set 15 | tocopilla
# Processing Record 22 of Set 15 | plotnikovo
# Processing Record 23 of Set 15 | akdepe
# Processing Record 24 of Set 15 | chifeng
# Processing Record 25 of Set 15 | sao felix do xingu
# Processing Record 26 of Set 15 | malanje
# Processing Record 27 of Set 15 | coahuayana
# Processing Record 28 of Set 15 | piacabucu
# Processing Record 29 of Set 15 | kharitonovo
# Processing Record 30 of Set 15 | flin flon
# Processing Record 31 of Set 15 | kannur
# Processing Record 32 of Set 15 | ye
# City not found. Skipping...
# Processing Record 33 of Set 15 | kruisfontein
# Processing Record 34 of Set 15 | beyneu
# Processing Record 35 of Set 15 | vengurla
# Processing Record 36 of Set 15 | sao jose da coroa grande
# Processing Record 37 of Set 15 | nizhniy kuranakh
# Processing Record 38 of Set 15 | guozhen
# Processing Record 39 of Set 15 | mwinilunga
# Processing Record 40 of Set 15 | goudomp
# City not found. Skipping...
# Processing Record 41 of Set 15 | nykoping
# Processing Record 42 of Set 15 | lima
# Processing Record 43 of Set 15 | singkawang
# Processing Record 44 of Set 15 | luganville
# Processing Record 45 of Set 15 | carutapera
# Processing Record 46 of Set 15 | muscat
# Processing Record 47 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 15 | auki
# Processing Record 49 of Set 15 | inta
# Processing Record 50 of Set 15 | henties bay
# Processing Record 1 of Set 16 | la crosse
# Processing Record 2 of Set 16 | kishi
# Processing Record 3 of Set 16 | abrau-dyurso
# Processing Record 4 of Set 16 | pinczow
# Processing Record 5 of Set 16 | oranjemund
# Processing Record 6 of Set 16 | sayat
# Processing Record 7 of Set 16 | hattem
# Processing Record 8 of Set 16 | cap malheureux
# Processing Record 9 of Set 16 | coruripe
# Processing Record 10 of Set 16 | loukhi
# Processing Record 11 of Set 16 | medvedka
# Processing Record 12 of Set 16 | praia
# Processing Record 13 of Set 16 | gumdag
# Processing Record 14 of Set 16 | sokoto
# Processing Record 15 of Set 16 | fruitville
# Processing Record 16 of Set 16 | soldotna
# Processing Record 17 of Set 16 | hualmay
# Processing Record 18 of Set 16 | aleppo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Waingapu', 'Country': 'ID', 'Lat': -9.6567, 'Lng': 120.2641, 'Max Temp': 77.45, 'Humidity': 74, 'Cloudiness': 61, 'Wind Speed': 12.35, 'Current Description': 'broken clouds'}, {'City': 'Hithadhoo', 'Country': 'MV', 'Lat': -0.6, 'Lng': 73.0833, 'Max Temp': 82.8, 'Humidity': 74, 'Cloudiness': 100, 'Wind Speed': 10.78, 'Current Description': 'overcast clouds'}, {'City': 'Barrow', 'Country': 'US', 'Lat': 71.2906, 'Lng': -156.7887, 'Max Temp': 28.42, 'Humidity': 86, 'Cloudiness': 100, 'Wind Speed': 4.61, 'Current Description': 'mist'}, {'City': 'The Valley', 'Country': 'AI', 'Lat': 18.217, 'Lng': -63.0578, 'Max Temp': 82.26, 'Humidity': 78, 'Cloudiness': 21, 'Wind Speed': 19.01, 'Current Description': 'few clouds'}, {'City': 'Yellowknife', 'Country': 'CA', 'Lat': 62.456, 'Lng': -114.3525, 'Max Temp': 51.39, 'Humidity': 73, 'Cloudiness': 99, 'Wind Speed': 10.96, 'Current Description': 'overcast clouds'}, {'City': 'Grand Gaube', 'Country': 'MU', 'Lat': -20.0064, 'Lng': 57.6608, 'Max Temp': 71.38, 'Humidity': 88, 'Cloudiness': 91, 'Wind Speed': 10, 'Current Description': 'moderate rain'}, {'City': 'Ushuaia', 'Country': 'AR', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 41.77, 'Humidity': 96, 'Cloudiness': 100, 'Wind Speed': 4.9, 'Current Description': 'overcast clouds'}, {'City': 'Bethel', 'Country': 'US', 'Lat': 41.3712, 'Lng': -73.414, 'Max Temp': 62.96, 'Humidity': 91, 'Cloudiness': 0, 'Wind Speed': 0, 'Current Description': 'clear sky'}, {'City': 'Hobyo', 'Country': 'SO', 'Lat': 5.3505, 'Lng': 48.5268, 'Max Temp': 84.63, 'Humidity': 65, 'Cloudiness': 99, 'Wind Speed': 26.73, 'Current Description': 'overcast clouds'}, {'City': 'Dingle', 'Country': 'PH', 'Lat': 10.9995, 'Lng': 122.6711, 'Max Temp': 80.06, 'Humidity': 81, 'Cloudiness': 82, 'Wind Speed': 4.27, 'Current Description': 'broken clouds'}, {'City': 'Lodwar', 'Country': 'KE', 'Lat': 3.1191, 'Lng': 35.5973, 'Max Temp': 93.43, 'Humidity': 30, 'Cloudiness': 5, 'Wind Speed': 11.18, 'Current Description': 'clear sky'}, {'City': 'Rikitea', 'Country': 'PF', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 73.02, 'Humidity': 63, 'Cloudiness': 46, 'Wind Speed': 8.81, 'Current Description': 'scattered clouds'}, {'City': 'Naifaru', 'Country': 'MV', 'Lat': 5.4444, 'Lng': 73.3657, 'Max Temp': 83.59, 'Humidity': 76, 'Cloudiness': 94, 'Wind Speed': 14.81, 'Current Description': 'light rain'}, {'City': 'Mataura', 'Country': 'NZ', 'Lat': -46.1927, 'Lng': 168.8643, 'Max Temp': 36.48, 'Humidity': 95, 'Cloudiness': 21, 'Wind Speed': 2.89, 'Current Description': 'few clouds'}, {'City': 'Butaritari', 'Country': 'KI', 'Lat': 3.0707, 'Lng': 172.7902, 'Max Temp': 81.84, 'Humidity': 75, 'Cloudiness': 20, 'Wind Speed': 11.45, 'Current Description': 'few clouds'}, {'City': 'Emerald', 'Country': 'AU', 'Lat': -23.5333, 'Lng': 148.1667, 'Max Temp': 48.34, 'Humidity': 73, 'Cloudiness': 86, 'Wind Speed': 8.41, 'Current Description': 'overcast clouds'}, {'City': 'Victoria', 'Country': 'HK', 'Lat': 22.2855, 'Lng': 114.1577, 'Max Temp': 85.32, 'Humidity': 86, 'Cloudiness': 100, 'Wind Speed': 11.01, 'Current Description': 'overcast clouds'}, {'City': 'Makubetsu', 'Country': 'JP', 'Lat': 45.3714, 'Lng': 141.8211, 'Max Temp': 45.99, 'Humidity': 96, 'Cloudiness': 92, 'Wind Speed': 15.75, 'Current Description': 'overcast clouds'}, {'City': 'Tezu', 'Country': 'IN', 'Lat': 27.9167, 'Lng': 96.1667, 'Max Temp': 74.07, 'Humidity': 95, 'Cloudiness': 100, 'Wind Speed': 5.01, 'Current Description': 'overcast clouds'}, {'City': 'Ust-Tsilma', 'Country': 'RU', 'Lat': 65.441, 'Lng': 52.1498, 'Max Temp': 62.56, 'Humidity': 26, 'Cloudiness': 0, 'Wind Speed': 8.32, 'Current Description': 'clear sky'}, {'City': 'Sijunjung', 'Country': 'ID', 'Lat': -0.6876, 'Lng': 100.9537, 'Max Temp': 75.27, 'Humidity': 92, 'Cloudiness': 96, 'Wind Speed': 1.12, 'Current Description': 'overcast clouds'}, {'City': 'Bull Savanna', 'Country': 'JM', 'Lat': 17.8868, 'Lng': -77.5902, 'Max Temp': 73.87, 'Humidity': 83, 'Cloudiness': 46, 'Wind Speed':  ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Waingapu      ID  -9.6567  120.2641     77.45        74          61
# 1    Hithadhoo      MV  -0.6000   73.0833     82.80        74         100
# 2       Barrow      US  71.2906 -156.7887     28.42        86         100
# 3   The Valley      AI  18.2170  -63.0578     82.26        78          21
# 4  Yellowknife      CA  62.4560 -114.3525     51.39        73          99
# 5  Grand Gaube      MU -20.0064   57.6608     71.38        88          91
# 6      Ushuaia      AR -54.8000  -68.3000     41.77        96         100
# 7       Bethel      US  41.3712  -73.4140     62.96        91           0
# 8        Hobyo      SO   5.3505   48.5268     84.63        65          99
# 9       Dingle      PH  10.9995  122.6711     80.06        81          82
#
#    Wind Speed Current Description
# 0       12.35       broken clouds
# 1       10.78     overcast clouds
# 2        4.61                mist
# 3       19.01          few clouds
# 4       10.96     overcast clouds
# 5       10.00       moderate rain
# 6        4.90     overcast clouds
# 7        0.00           clear sky
# 8       26.73     overcast clouds
# 9        4.27       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
